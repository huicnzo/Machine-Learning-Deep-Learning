# %% [markdown]
# *deep learning  is a technique  used to mimic the human brain .
#
# *first simplest type of  NN is perceptron
#
# *bcoz of back propagation ANN , CNN & RNN became so efficient
#
# *ppl call NN a blackbox coz they are hard to understand .
#
# # *What NN do & how they do it?

# %% [markdown]
# Let's consider a case drug is tested which is designed to treat a disease
# we gave that drug to three diff groups
# 1) Low dosages 2) Medium dosages 3) High dosgaes
# (no effect)      (effective)      (no effect)
#
# A NN consists of nodes & connections between the nodes .
#
# There are different layers of nodes inside NN .
# the layers between input & output layers are called hidden layers .
# When you build a NN you decide how many hidden layers you want & how many nodes go into each node .
