# %% [markdown]
# # Activation Function Part -1

# %% [markdown]
# Sigmoid function

# %% [markdown]
# ![11f74b8a-dde5-4b67-a62d-19d9abba80c7.png](attachment:11f74b8a-dde5-4b67-a62d-19d9abba80c7.png)

# %% [markdown]
# ReLu function   .. much more popular than Sigmoid

# %% [markdown]
# ![11f74b8a-dde5-4b67-a62d-19d9abba80c7%20%281%29.png](attachment:11f74b8a-dde5-4b67-a62d-19d9abba80c7%20%281%29.png)

# %% [markdown]
# this is just to give a basic mathematical idea for Sigmoid & ReLu function .
